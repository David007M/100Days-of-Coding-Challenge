# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
house = pd.read_csv("data/kc_house_data.csv")

# %%
ufos = pd.read_csv("data/nuforc_reports.csv", parse_dates=["date_time", "posted"])

# %%
titanic["sex"].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
titanic["sex"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

# %%
titanic["sex"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
titanic["sex"].value_counts().plot(kind="bar", title="Sex Breakdown From Titanic")
# Out:
# <AxesSubplot:title={'center':'Sex Breakdown From Titanic'}>

# %%
titanic["sex"].value_counts().plot(kind="bar")
plt.title("My Title", loc="right")
# Out:
# Text(1.0, 1.0, 'My Title')

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    xlabel="Month",
    ylabel="Num Sighting",
    fontsize="10")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2512\1734851626.py in <module>
# ----> 1 sightings = ufos.month.value_counts().sort_index()
#       2 sightings.plot(
#       3     kind="bar",
#       4     title="UFO Sightings By Month",
#       5     xlabel="Month",
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="10")
plt.xlabel("Month", fontsize=24, color="blue")
plt.ylabel("Num Sighting", fontsize=24, color="Purple")

# %%
sightings

# %%
months_dict = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May", 6: "Jun", 7:"Jul", 8: "Aug", 9:"Sep", 10: "Oct", 11: "Nov", 12: "Dec"}
sightings.rename(months_dict)

# %%
sightings.rename(months_dict).plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="20")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)

# %%
salaries = pd.read_csv("data/Salaries.csv", low_memory=False)
salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors="coerce").fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors="coerce").fillna(0)
#salaries

# %%
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]

# %%
df.set_index("EmployeeName", inplace=True)

# %%
df.head(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %%
df.head(10).plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.barh(color="red", title="Highest Paid SF Employees")
# Out:
# <AxesSubplot:title={'center':'Highest Paid SF Employees'}, ylabel='EmployeeName'>

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)
# Out:
# <AxesSubplot:ylabel='EmployeeName'>

# %% [markdown]
# # Exercise _ plotting with Pandas

# %%
arts = pd.read_csv("data/billboard_charts.csv")
arts
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
arts = pd.read_csv("data/billboard_charts.csv", parse_dates=["date"])

top = arts[arts["rank"] == 1]["artist"].value_counts().head(10)
plt.style.use("ggplot")
top.plot(
    kind="barh",
    title="Artists With Most Weeks At #1",
    figsize=(8,6),
    edgecolor="black",
    linewidth=3
)
plt.xlabel("Weeks At #1")
# Out:
# Text(0.5, 0, 'Weeks At #1')

# %%
df["BasePay"].plot(kind="hist", bins=200, color="purple")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind="hist", bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'BasePay'}>,
#         <AxesSubplot:title={'center':'OvertimePay'}>],
#        [<AxesSubplot:title={'center':'OtherPay'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="box", showfliers=False)
# Out:
# <AxesSubplot:>

# %%
titanic.plot()
# Out:
# <AxesSubplot:>

# %%
ufos.date_time.dt.year.value_counts().sort_index().plot(kind="line", color="olive", linewidth=5, linestyle=":")
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %%
house.plot.line(x="bedrooms", y="price")
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %% [markdown]
# # Exercise _ plotting with Pandas

# %%
artists = arts[arts["song"] == "Please Mr. Postman"]["artist"].value_counts()

# %%
colors = ["#6c5ce7","#00cec9", "#74b9ff"]
artists.plot(
    kind="pie", 
    colors=colors, 
    explode=(0,0,0.1),
    title="Please Mr. Postman Versions")
# Out:
# <AxesSubplot:title={'center':'Please Mr. Postman Versions'}, ylabel='artist'>

# %%
arts[arts["song"] == "Please Mr. Postman"]
# Out:
#              date  rank                song             artist  last-week  \
# 201695 1983-03-19    96  Please Mr. Postman  Gentle Persuasion       82.0
# 201781 1983-03-12    82  Please Mr. Postman  Gentle Persuasion       82.0
# 201881 1983-03-05    82  Please Mr. Postman  Gentle Persuasion       89.0
# 201988 1983-02-26    89  Please Mr. Postman  Gentle Persuasion        NaN
# 243465 1975-03-15    79  Please Mr. Postman         Carpenters       62.0
# 243548 1975-03-08    62  Please Mr. Postman         Carpenters       44.0
# 243630 1975-03-01    44  Please Mr. Postman         Carpenters       38.0
# 243724 1975-02-22    38  Please Mr. Postman         Carpenters       25.0
# 243811 1975-02-15    25  Please Mr. Postman         Carpenters       15.0
# 243901 1975-02-08    15  Please Mr. Postman         Carpenters        6.0
# 243992 1975-02-01     6  Please Mr. Postman         Carpenters        1.0
# 244087 1975-01-25     1  Please Mr. Postman         Carpenters        2.0
# ...

# %%
house.plot.scatter(x="bedrooms", y="bathrooms", color="red")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
house.plot.scatter(x="bedrooms", y="bathrooms", marker="X")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
ufos[ufos["state"] == "CA"].date_time.dt.year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"] == "TX"].date_time.dt.year.value_counts().sort_index().plot(label="TX")
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
arts[arts["song"] == "Blinding Lights"].set_index("date")["rank"].plot(
    figsize=(9,5),
    title="Blinding Lights Chart Performance",
    color="#a29bfe",
    linewidth=3
)
plt.gca().invert_yaxis()

# %%
ufos["shape"].value_counts()
# Out:
# light        18230
# circle       10130
# triangle      7910
# fireball      7095
# unknown       6182
# sphere        6065
# other         5749
# disk          4522
# oval          3857
# formation     2842
# changing      2112
# cigar         1990
# flash         1675
# rectangle     1597
# cylinder      1374
# diamond       1273
# chevron        953
# teardrop       767
# egg            666
# cone           349
# cross          289
# Name: shape, dtype: int64

# %%
ufos[ufos["shape"] == "formation"].date_time.dt.year.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] == "oval"].date_time.dt.year.value_counts().sort_index().plot(label="oval")
ufos[ufos["shape"] == "light"].date_time.dt.year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"] == "circle"].date_time.dt.year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "fireball"].date_time.dt.year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "disk"].date_time.dt.year.value_counts().sort_index().plot(label="disk")
plt.xlim(2000,2020)
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
df
# Out:
#                      BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00  400184.25
# GARY JIMENEZ       155966.02    245131.88  137811.38
# ALBERT PARDINI     212739.13    106088.18   16452.60
# CHRISTOPHER CHONG   77916.00     56120.71  198306.90
# PATRICK GARDNER    134401.60      9737.00  182234.59
# ...                      ...          ...        ...
# Roy I Tillery           0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Joe Lopez               0.00         0.00    -618.13
#
# [148654 rows x 3 columns]

# %%
df.plot(kind="hist", subplots=True, sharex=False, figsize=(6,5), )
plt.tight_layout()

# %%
df.plot(kind="hist", subplots=True, sharex=False, layout=(1,3), figsize=(10,5), bins=30)
plt.tight_layout()

# %%
axs = df.plot(kind="hist", subplots=True, sharex=False, layout=(1,3), figsize=(10,5), bins=30)
plt.tight_layout()
axs[0][2].set_xlim(0,20000)
axs[0][1].set_title("Middle")
axs[0][0].set_title("First")
axs[0][2].set_title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %%
ufos.date_time.dt.year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
ufos.date_time.dt.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(1,2)
ufos.date_time.dt.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufos.date_time.dt.month.value_counts().sort_index().plot(kind="bar", ax=axs[1])
axs[1].set_title("Sightings By Month")
# Out:
# Text(0.5, 1.0, 'Sightings By Month')

# %%
months = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 
          7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
fig, axs = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle("UFO sightings by month", fontsize=14)
fig.tight_layout(pad=2)
ufos[ufos.date_time.dt.year == 2014].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][0], title="2014")
ufos[ufos.date_time.dt.year == 2015].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][1], title="2015")
ufos[ufos.date_time.dt.year == 2016].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][2], title="2016")
ufos[ufos.date_time.dt.year == 2017].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][0], title="2017")
ufos[ufos.date_time.dt.year == 2018].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][1], title="2018")
ufos[ufos.date_time.dt.year == 2019].date_time.dt.month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][2], title="2019")
plt.tight_layout()

# %% [markdown]
# # Exercise

# %%
billboard = pd.read_csv("data/billboard_charts.csv", parse_dates=["date"])
billboard
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
plt.figure(figsize=(10,7))
df = billboard[billboard["date"].between("2016-12-25", "2021-01-01")].set_index("date")
all_i_want = df[df["song"] == "All I Want For Christmas Is You"]
all_i_want["rank"].plot(label="All I Want For Christmas Is You")

rockin = df[(df["song"] == "Rockin' Around The Christmas Tree") & (df["artist"] == "Brenda Lee")]
rockin["rank"].plot(label="Rockin' Around The Christmas Tree")

jingle = df[df["song"] == "Jingle Bell Rock"]
jingle["rank"].plot(label="Jingle Bell Rock")

plt.legend()
plt.ylabel("Chart Rank")
plt.title("Christmas Songs On The Hot 100")
plt.xticks(
    ["2016-12-25", "2017-12-25","2018-12-25","2019-12-25","2020-12-25"],
    labels=["Xmas 2016", "Xmas 2017","Xmas 2018","Xmas 2019","Xmas 2020",]
)

plt.gca().invert_yaxis()

# %%
jl = billboard[billboard["artist"] == "John Lennon"]["song"].value_counts().head(8)
wings = billboard[billboard["artist"] == "Wings"]["song"].value_counts().head(8)
gh = billboard[billboard["artist"] == "George Harrison"]["song"].value_counts().head(8)
rs = billboard[billboard["artist"] == "Ringo Starr"]["song"].value_counts().head(8)

fig, axs = plt.subplots(2,2, figsize=(14,8))
fig.suptitle("Beatles Solo Songs (By Weeks On Chart)", fontsize=20 )

jl.plot(kind="barh", ax=axs[0][0], color="#fc5c65")
axs[0][0].set_title("John Lennon", color="#fc5c65")

wings.plot(kind="barh", ax=axs[0][1], color="#fd9644")
axs[0][1].set_title("Wings(Paul)", color="#fd9644")

gh.plot(kind="barh", ax=axs[1][0], color="#2bcbba")
axs[1][0].set_title("George Harrison", color="#2bcbba")

rs.plot(kind="barh", ax=axs[1][1], color="#26de81")
axs[1][1].set_title("Ringo Starr", color="#26de81")


plt.tight_layout()
